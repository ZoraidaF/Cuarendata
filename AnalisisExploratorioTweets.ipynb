# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('train.csv', low_memory=False)
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Limpiando caracteres especiales

# %%
df['text'] = df['text'].str.replace("[^a-z A-Z 0-9 # @]", " ") #selecciono solo esos caracteres
df['text'] = df['text'].str.lower() #Convierto Mayuscula en minuscula
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  our deeds are the reason of this #earthquake m...
# 1   4     NaN      NaN             forest fire near la ronge sask  canada
# 2   5     NaN      NaN  all residents asked to  shelter in place  are ...
# 3   6     NaN      NaN  13 000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  just got sent this photo from ruby #alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Obteniendo palabras mayor a 3 caracteres

# %%
df['text'] = df['text'].apply(lambda x: ( [ word for word in x.split() if len(word)>3 ]) )
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  [deeds, reason, this, #earthquake, allah, forg...
# 1   4     NaN      NaN          [forest, fire, near, ronge, sask, canada]
# 2   5     NaN      NaN  [residents, asked, shelter, place, being, noti...
# 3   6     NaN      NaN  [people, receive, #wildfires, evacuation, orde...
# 4   7     NaN      NaN  [just, sent, this, photo, from, ruby, #alaska,...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Analizamos las palabras que se encuentra en text

# %%
def contarFrecuenciaDePalabras(unaLista,lista):
   
        for palabra in unaLista:
            try:    
                if palabra not in lista:
                    lista[palabra] = 0
                lista[palabra] += 1  
            except UnicodeEncodeError:
                continue

# %%
# Se recuerda que los elementos que tiene la columna text esta como una lista de palabras
lista={} #es la lista que generaremos de todas las palabras que exista en la columna text
a=df['text'].apply(lambda unaLista: contarFrecuenciaDePalabras(unaLista,lista))

# %%
palabraYFrecuencia=sorted(lista.items(), key= lambda x: x[1], reverse = True)
palabraYFrecuencia
# Out:
# [('http', 4309),
#  ('that', 625),
#  ('with', 574),
#  ('this', 480),
#  ('from', 422),
#  ('https', 412),
#  ('have', 386),
#  ('like', 348),
#  ('just', 323),
#  ('your', 293),
#  ('after', 259),
#  ('will', 258),
#  ('when', 255),
#  ('fire', 250),
#  ('they', 231),
#  ('what', 223),
#  ('more', 218),
#  ('about', 214),
#  ('people', 198),
#  ('been', 191),
#  ('over', 190),
#  ('there', 189),
#  ('into', 174),
#  ('video', 162),
#  ('emergency', 153),
#  ('disaster', 150),
#  ('police', 142),
#  ('than', 139),
#  ('would', 137),
#  ('body', 130),
#  ('some', 129),
#  ('still', 129),
#  ('were', 126),
#  ('news', 121),
#  ('burning', 121),
#  ('back', 119),
#  ('storm', 119),
#  ('suicide', 119),
#  ('crash', 117),
#  ('california', 116),
#  ('time', 116),
#  ('them', 115),
#  ('know', 113),
#  ('buildings', 111),
#  ('first', 109),
#  ('going', 104),
#  ('bomb', 104),
#  ('fires', 101),
#  ('attack', 101),
#  ('today', 100),
#  ('here', 99),
#  ('love', 98),
#  ('year', 98),
#  ('killed', 98),
#  ('dead', 97),
#  ('world', 95),
#  ('nuclear', 95),
#  ('their', 94),
#  ('full', 94),
#  ('train', 93),
#  ('being', 90),
#  ('life', 89),
#  ('only', 89),
#  ('good', 89),
#  ('down', 88),
#  ('families', 87),
#  ('think', 86),
#  ('accident', 85),
#  ('many', 84),
#  ('watch', 84),
#  ('last', 83),
#  ('could', 83),
#  ('@youtube', 83),
#  ('home', 82),
#  ('2015', 81),
#  ('make', 80),
#  ('want', 80),
#  ('then', 80),
#  ('years', 79),
#  ('collapse', 75),
#  ('work', 74),
#  ('because', 74),
#  ('#news', 74),
#  ('death', 74),
#  ('mass', 74),
#  ('look', 73),
#  ('help', 73),
#  ('please', 73),
#  ('even', 73),
#  ('another', 72),
#  ('need', 72),
#  ('army', 72),
#  ('take', 72),
#  ('really', 71),
#  ('hiroshima', 71),
#  ('should', 70),
#  ('bombing', 70),
#  ('school', 68),
#  ('black', 68),
#  ('right', 68),
#  ('those', 68),
#  ('fatal', 67),
#  ('water', 66),
#  ('mh370', 65),
#  ('much', 64),
#  ('city', 64),
#  ('read', 64),
#  ('northern', 64),
#  ('wildfire', 64),
#  ('forest', 63),
#  ('never', 63),
#  ('obama', 63),
#  ('great', 62),
#  ('live', 61),
#  ('where', 61),
#  ('homes', 61),
#  ('legionnaires', 61),
#  ('bomber', 61),
#  ('wreck', 60),
#  ('latest', 60),
#  ('every', 59),
#  ('reddit', 59),
#  ('atomic', 58),
#  ('typhoon', 58),
#  ('everyone', 57),
#  ('said', 57),
#  ('fear', 57),
#  ('near', 56),
#  ('getting', 56),
#  ('damage', 56),
#  ('shit', 56),
#  ('ever', 56),
#  ('come', 56),
#  ('under', 56),
#  ('injured', 56),
#  ('flames', 56),
#  ('content', 56),
#  ('while', 55),
#  ('feel', 55),
#  ('flood', 54),
#  ('floods', 54),
#  ('most', 53),
#  ('since', 53),
#  ('cross', 53),
#  ('before', 52),
#  ('found', 52),
#  ('state', 52),
#  ('hope', 52),
#  ('coming', 51),
#  ('night', 51),
#  ('next', 51),
#  ('stop', 51),
#  ('during', 51),
#  ('without', 51),
#  ('these', 50),
#  ('truck', 50),
#  ('debris', 50),
#  ('little', 50),
#  ('evacuation', 49),
#  ('area', 49),
#  ('times', 49),
#  ('which', 49),
#  ('well', 49),
#  ('japan', 49),
#  ('plan', 49),
#  ('smoke', 48),
#  ('face', 48),
#  ('cause', 48),
#  ('weather', 48),
#  ('wounded', 48),
#  ('malaysia', 48),
#  ('heat', 47),
#  ('wild', 47),
#  ('high', 47),
#  ('movie', 47),
#  ('through', 47),
#  ('confirmed', 47),
#  ('severe', 47),
#  ('flooding', 46),
#  ('always', 46),
#  ('check', 46),
#  ('fucking', 46),
#  ('explosion', 46),
#  ('looks', 46),
#  ('food', 46),
#  ('military', 46),
#  ('made', 46),
#  ('rain', 45),
#  ('best', 45),
#  ('bloody', 45),
#  ('services', 45),
#  ('blood', 45),
#  ('warning', 45),
#  ('weapon', 45),
#  ('says', 45),
#  ('sinking', 45),
#  ('thunderstorm', 45),
#  ('devastated', 45),
#  ('until', 44),
#  ('also', 44),
#  ('house', 44),
#  ('liked', 44),
#  ('fall', 44),
#  ('weapons', 44),
#  ('lightning', 44),
#  ('bags', 44),
#  ('natural', 44),
#  ('spill', 44),
#  ('injuries', 44),
#  ('loud', 44),
#  ('gonna', 43),
#  ('head', 43),
#  ('tonight', 43),
#  ('someone', 43),
#  ('screaming', 43),
#  ('family', 43),
#  ('again', 43),
#  ('missing', 43),
#  ('summer', 42),
#  ('injury', 42),
#  ('murder', 42),
#  ('wind', 42),
#  ('evacuate', 42),
#  ('trapped', 42),
#  ('collided', 42),
#  ('fatalities', 42),
#  ('whole', 41),
#  ('save', 41),
#  ('survive', 41),
#  ('hail', 41),
#  ('girl', 41),
#  ('released', 41),
#  ('attacked', 41),
#  ('explode', 41),
#  ('derailment', 41),
#  ('failure', 41),
#  ('harm', 41),
#  ('collision', 41),
#  ('rescue', 41),
#  ('migrants', 41),
#  ('thunder', 41),
#  ('wreckage', 41),
#  ('outbreak', 41),
#  ('photo', 40),
#  ('week', 40),
#  ('around', 40),
#  ('free', 40),
#  ('long', 40),
#  ('destroyed', 40),
#  ('post', 40),
#  ('bridge', 40),
#  ('hazard', 40),
#  ('china', 40),
#  ('deaths', 40),
#  ('panic', 40),
#  ('sinkhole', 40),
#  ('other', 39),
#  ('update', 39),
#  ('burned', 39),
#  ('does', 39),
#  ('road', 39),
#  ('game', 39),
#  ('island', 39),
#  ('ambulance', 39),
#  ('destroy', 39),
#  ('destruction', 39),
#  ('women', 39),
#  ('charged', 39),
#  ('fuck', 39),
#  ('story', 39),
#  ('keep', 39),
#  ('report', 39),
#  ('rescuers', 39),
#  ('lives', 39),
#  ('rescued', 39),
#  ('twister', 39),
#  ('windstorm', 39),
#  ('county', 38),
#  ('trauma', 38),
#  ('survivors', 38),
#  ('self', 38),
#  ('away', 38),
#  ('show', 38),
#  ('against', 38),
#  ('white', 38),
#  ('real', 38),
#  ('saudi', 38),
#  ('battle', 38),
#  ('bombed', 38),
#  ('hurricane', 38),
#  ('boat', 38),
#  ('ruin', 38),
#  ('service', 38),
#  ('dust', 38),
#  ('survived', 38),
#  ('sunk', 38),
#  ('wrecked', 38),
#  ('thing', 37),
#  ('crashed', 37),
#  ('august', 37),
#  ('violent', 37),
#  ('things', 37),
#  ('twitter', 37),
#  ('woman', 37),
#  ('half', 37),
#  ('displaced', 37),
#  ('hazardous', 37),
#  ('crush', 37),
#  ('curfew', 37),
#  ('devastation', 37),
#  ('famine', 37),
#  ('investigators', 37),
#  ('massacre', 37),
#  ('quarantine', 37),
#  ('structural', 37),
#  ('sandstorm', 37),
#  ('better', 36),
#  ('least', 36),
#  ('came', 36),
#  ('suspect', 36),
#  ('call', 36),
#  ('kills', 36),
#  ('change', 36),
#  ('mosque', 36),
#  ('terrorist', 36),
#  ('hostage', 36),
#  ('wanna', 36),
#  ('catastrophe', 36),
#  ('collapsed', 36),
#  ('danger', 36),
#  ('deluge', 36),
#  ('derailed', 36),
#  ('refugees', 36),
#  ('drowning', 36),
#  ('engulfed', 36),
#  ('screamed', 36),
#  ('bang', 36),
#  ('quarantined', 36),
#  ('tornado', 35),
#  ('wave', 35),
#  ('past', 35),
#  ('heard', 35),
#  ('airplane', 35),
#  ('phone', 35),
#  ('national', 35),
#  ('heart', 35),
#  ('tomorrow', 35),
#  ('part', 35),
#  ('group', 35),
#  ('power', 35),
#  ('bleeding', 35),
#  ('light', 35),
#  ('tragedy', 35),
#  ('blown', 35),
#  ('anniversary', 35),
#  ('cliff', 35),
#  ('hundreds', 35),
#  ('stock', 35),
#  ('derail', 35),
#  ('detonate', 35),
#  ('exploded', 35),
#  ('hijacker', 35),
#  ('inundated', 35),
#  ('screams', 35),
#  ('whirlwind', 35),
#  ('horrible', 34),
#  ('left', 34),
#  ('meltdown', 34),
#  ('plane', 34),
#  ('must', 34),
#  ('went', 34),
#  ('blew', 34),
#  ('drown', 34),
#  ('rioting', 34),
#  ('riot', 34),
#  ('traumatised', 34),
#  ('casualties', 34),
#  ('landslide', 34),
#  ('wounds', 34),
#  ('desolation', 34),
#  ('electrocuted', 34),
#  ('hostages', 34),
#  ('razed', 34),
#  ('something', 33),
#  ('thank', 33),
#  ('reunion', 33),
#  ('iran', 33),
#  ('zone', 33),
#  ('soon', 33),
#  ('apocalypse', 33),
#  ('land', 33),
#  ('bagging', 33),
#  ('caused', 33),
#  ('drought', 33),
#  ('catastrophic', 33),
#  ('affected', 33),
#  ('collide', 33),
#  ('demolish', 33),
#  ('trouble', 33),
#  ('evacuated', 33),
#  ('flattened', 33),
#  ('lava', 33),
#  ('murderer', 33),
#  ('mudslide', 33),
#  ('panicking', 33),
#  ('south', 32),
#  ('very', 32),
#  ('minute', 32),
#  ('doing', 32),
#  ('possible', 32),
#  ('sure', 32),
#  ('river', 32),
#  ('kill', 32),
#  ('fedex', 32),
#  ('market', 32),
#  ('send', 32),
#  ('fatality', 32),
#  ('hijacking', 32),
#  ('pandemonium', 32),
#  ('three', 31),
#  ('breaking', 31),
#  ('kids', 31),
#  ('america', 31),
#  ('goes', 31),
#  ('government', 31),
#  ('annihilated', 31),
#  ('thought', 31),
#  ('arson', 31),
#  ('terrorism', 31),
#  ('officials', 31),
#  ('longer', 31),
#  ('blazing', 31),
#  ('song', 31),
#  ('baby', 31),
#  ('casualty', 31),
#  ('chemical', 31),
#  ('responders', 31),
#  ('crushed', 31),
#  ('detonation', 31),
#  ('drowned', 31),
#  ('earthquake', 31),
#  ('obliterated', 31),
#  ('rainstorm', 31),
#  ('detonated', 31),
#  ('building', 30),
#  ('thanks', 30),
#  ('care', 30),
#  ('used', 30),
#  ('issues', 30),
#  ('same', 30),
#  ('fight', 30),
#  ('armageddon', 30),
#  ('sound', 30),
#  ('stay', 30),
#  ('beautiful', 30),
#  ('calgary', 30),
#  ('bioterror', 30),
#  ('nothing', 30),
#  ('shoulder', 30),
#  ('officer', 30),
#  ('cyclone', 30),
#  ('blast', 30),
#  ('demolition', 30),
#  ('volcano', 30),
#  ('tsunami', 30),
#  ('electrocute', 30),
#  ('#hot', 30),
#  ('#prebreak', 30),
#  ('#best', 30),
#  ('obliterate', 30),
#  ('siren', 30),
#  ('days', 29),
#  ('cool', 29),
#  ('already', 29),
#  ('making', 29),
#  ('done', 29),
#  ('believe', 29),
#  ('ebay', 29),
#  ('hours', 29),
#  ('start', 29),
#  ('media', 29),
#  ('remember', 29),
#  ('security', 29),
#  ('bush', 29),
#  ('demolished', 29),
#  ('airport', 29),
#  ('eyewitness', 29),
#  ('obliteration', 29),
#  ('offensive', 29),
#  ('upheaval', 29),
#  ('died', 28),
#  ('second', 28),
#  ('ablaze', 28),
#  ('inside', 28),
#  ('leave', 28),
#  ('traffic', 28),
#  ('shooting', 28),
#  ('actually', 28),
#  ('wake', 28),
#  ('sirens', 28),
#  ('peace', 28),
#  ('person', 28),
#  ('music', 28),
#  ('having', 28),
#  ('words', 28),
#  ('blight', 28),
#  ('such', 28),
#  ('turkey', 28),
#  ('hellfire', 28),
#  ('hijack', 28),
#  ('16yr', 28),
#  ('both', 27),
#  ('site', 27),
#  ('shot', 27),
#  ('north', 27),
#  ('support', 27),
#  ('plans', 27),
#  ('play', 27),
#  ('stand', 27),
#  ('order', 27),
#  ('israeli', 27),
#  ('trying', 27),
#  ('line', 27),
#  ('policy', 27),
#  ('nearby', 27),
#  ('deluged', 27),
#  ('declares', 27),
#  ('seismic', 27),
#  ('reactor', 27),
#  ('snowstorm', 27),
#  ('place', 26),
#  ('wait', 26),
#  ('west', 26),
#  ('didn', 26),
#  ('gets', 26),
#  ('yourself', 26),
#  ('brown', 26),
#  ('anything', 26),
#  ('yeah', 26),
#  ('guys', 26),
#  ('deal', 26),
#  ('doesn', 26),
#  ('find', 26),
#  ('memories', 26),
#  ('soudelor', 26),
#  ('rubble', 26),
#  ('swallowed', 26),
#  ('lost', 25),
#  ('outside', 25),
#  ('tell', 25),
#  ('almost', 25),
#  ('country', 25),
#  ('horror', 25),
#  ('hell', 25),
#  ('maybe', 25),
#  ('data', 25),
#  ('children', 25),
#  ('american', 25),
#  ('health', 25),
#  ('photos', 25),
#  ('watching', 25),
#  ('bigger', 25),
#  ('rise', 25),
#  ('desolate', 25),
#  ('saipan', 25),
#  ('conclusively', 25),
#  ('street', 24),
#  ('side', 24),
#  ('center', 24),
#  ('anyone', 24),
#  ('helicopter', 24),
#  ('history', 24),
#  ('pick', 24),
#  ('control', 24),
#  ('makes', 24),
#  ('literally', 24),
#  ('transport', 24),
#  ('bioterrorism', 24),
#  ('searching', 24),
#  ('hear', 24),
#  ('crews', 24),
#  ('waves', 24),
#  ('bodies', 24),
#  ('projected', 24),
#  ('happy', 23),
#  ('#nowplaying', 23),
#  ('finally', 23),
#  ('might', 23),
#  ('eyes', 23),
#  ('everything', 23),
#  ('amid', 23),
#  ('blaze', 23),
#  ('damn', 23),
#  ('team', 23),
#  ('feeling', 23),
#  ('avalanche', 23),
#  ('hollywood', 23),
#  ('pretty', 23),
#  ('book', 23),
#  ('move', 23),
#  ('online', 23),
#  ('though', 23),
#  ('probably', 23),
#  ('myself', 23),
#  ('saved', 23),
#  ('trains', 23),
#  ('aircraft', 23),
#  ('signs', 23),
#  ('effect', 23),
#  ('#islam', 23),
#  ('manslaughter', 23),
#  ('trench', 23),
#  ('fast', 22),
#  ('property', 22),
#  ('once', 22),
#  ('wrong', 22),
#  ('feared', 22),
#  ('hate', 22),
#  ('seen', 22),
#  ('case', 22),
#  ('annihilation', 22),
#  ('major', 22),
#  ('child', 22),
#  ('name', 22),
#  ('crisis', 22),
#  ('leather', 22),
#  ('caught', 22),
#  ('town', 22),
#  ('okay', 22),
#  ('youth', 22),
#  ('space', 22),
#  ('nearly', 22),
#  ('morning', 22),
#  ('money', 22),
#  ('spot', 22),
#  ('#hiroshima', 22),
#  ('sensor', 22),
#  ('refugio', 22),
#  ('costlier', 22),
#  ('stretcher', 22),
#  ('miners', 22),
#  ('flash', 21),
#  ('flag', 21),
#  ('cars', 21),
#  ('lord', 21),
#  ('arsonist', 21),
#  ('huge', 21),
#  ('vehicle', 21),
#  ('daily', 21),
#  ('ship', 21),
#  ('crazy', 21),
#  ('sorry', 21),
#  ('ball', 21),
#  ('called', 21),
#  ('class', 21),
#  ('east', 21),
#  ('texas', 21),
#  ('india', 21),
#  ('worst', 21),
#  ('needs', 21),
#  ('giant', 21),
#  ('angry', 21),
#  ('isis', 21),
#  ('image', 21),
#  ('banned', 21),
#  ('knock', 21),
#  ('picking', 21),
#  ('reason', 20),
#  ('closed', 20),
#  ('heavy', 20),
#  ('across', 20),
#  ('haha', 20),
#  ('hard', 20),
#  ('others', 20),
#  ('talk', 20),
#  ('official', 20),
#  ('sign', 20),
#  ('poor', 20),
#  ('action', 20),
#  ('toddler', 20),
#  ('united', 20),
#  ('blue', 20),
#  ('star', 20),
#  ('australia', 20),
#  ('running', 20),
#  ('looking', 20),
#  ('dont', 20),
#  ('entire', 20),
#  ('level', 20),
#  ('link', 20),
#  ('meek', 20),
#  ('houses', 20),
#  ('become', 20),
#  ('chance', 20),
#  ('friends', 20),
#  ('ignition', 20),
#  ('#earthquake', 19),
#  ('wanted', 19),
#  ('thousands', 19),
#  ('alone', 19),
#  ('yours', 19),
#  ('else', 19),
#  ('happened', 19),
#  ('drive', 19),
#  ('couple', 19),
#  ('pakistan', 19),
#  ('totally', 19),
#  ('learn', 19),
#  ('beach', 19),
#  ('reports', 19),
#  ('christian', 19),
#  ('muslims', 19),
#  ('temple', 19),
#  ('view', 19),
#  ('taken', 19),
#  ('playing', 19),
#  ('anthrax', 19),
#  ('mishaps', 19),
#  ('public', 19),
#  ('computers', 19),
#  ('cake', 19),
#  ('pain', 19),
#  ('blizzard', 19),
#  ('large', 19),
#  ('ladies', 19),
#  ('appears', 19),
#  ('listen', 19),
#  ('centre', 19),
#  ('village', 19),
#  ('alarm', 19),
#  ('takes', 19),
#  ('issued', 19),
#  ('declaration', 19),
#  ('disea', 19),
#  ('chicago', 18),
#  ('front', 18),
#  ('aftershock', 18),
#  ('experts', 18),
#  ('trust', 18),
#  ('ready', 18),
#  ('human', 18),
#  ('film', 18),
#  ('till', 18),
#  ('friend', 18),
#  ('green', 18),
#  ('mount', 18),
#  ('driving', 18),
#  ('favorite', 18),
#  ('germs', 18),
#  ('info', 18),
#  ('drake', 18),
#  ('russian', 18),
#  ('middle', 18),
#  ('marks', 18),
#  ('thursday', 18),
#  ('#gbbo', 18),
#  ('downtown', 18),
#  ('british', 18),
#  ('instead', 18),
#  ('coaches', 18),
#  ('flight', 18),
#  ('quiz', 18),
#  ('virgin', 18),
#  ('bestnaijamade', 18),
#  ('bring', 17),
#  ('taking', 17),
#  ('reported', 17),
#  ('dies', 17),
#  ('turned', 17),
#  ('global', 17),
#  ('moment', 17),
#  ('behind', 17),
#  ('four', 17),
#  ('wednesday', 17),
#  ('early', 17),
#  ('reuters', 17),
#  ('driver', 17),
#  ('park', 17),
#  ('following', 17),
#  ('disease', 17),
#  ('comes', 17),
#  ('scared', 17),
#  ('escape', 17),
#  ('true', 17),
#  ('theater', 17),
#  ('gave', 17),
#  ('added', 17),
#  ('climate', 17),
#  ('party', 17),
#  ('turn', 17),
#  ('follow', 17),
#  ('fans', 17),
#  ('point', 17),
#  ('outrage', 17),
#  ('camp', 17),
#  ('sounds', 17),
#  ('landing', 17),
#  ('york', 17),
#  ('patience', 17),
#  ('former', 17),
#  ('madhya', 17),
#  ('pradesh', 17),
#  ('wonder', 17),
#  ('bayelsa', 17),
#  ('gems', 17),
#  ('funtenna', 17),
#  ('ancient', 17),
#  ('subreddits', 17),
#  ('galactic', 17),
#  ('awesome', 16),
#  ('upon', 16),
#  ('shots', 16),
#  ('risk', 16),
#  ('scene', 16),
#  ('seeing', 16),
#  ('thinking', 16),
#  ('mode', 16),
#  ('pakistani', 16),
#  ('wasn', 16),
#  ('share', 16),
#  ('give', 16),
#  ('series', 16),
#  ('hand', 16),
#  ('working', 16),
#  ('date', 16),
#  ('shows', 16),
#  ('lmao', 16),
#  ('claims', 16),
#  ('militants', 16),
#  ('bombs', 16),
#  ('pamela', 16),
#  ('young', 16),
#  ('miss', 16),
#  ('niggas', 16),
#  ('tweet', 16),
#  ('enough', 16),
#  ('told', 16),
#  ('falling', 16),
#  ('soul', 16),
#  ('rock', 16),
#  ('biggest', 16),
#  ('russia', 16),
#  ('pray', 16),
#  ('70th', 16),
#  ('holding', 16),
#  ('likely', 16),
#  ('businesses', 16),
#  ('room', 16),
#  ('download', 16),
#  ('break', 16),
#  ('sick', 16),
#  ('rules', 16),
#  ('lamp', 16),
#  ('hailstorm', 16),
#  ('nigerian', 16),
#  ('parole', 16),
#  ('unconfirmed', 16),
#  ('neighbour', 16),
#  ('mayhem', 16),
#  ('chile', 16),
#  ('expected', 15),
#  ('london', 15),
#  ('means', 15),
#  ('secret', 15),
#  ('guess', 15),
#  ('wants', 15),
#  ('tried', 15),
#  ('france', 15),
#  ('members', 15),
#  ('petition', 15),
#  ('hour', 15),
#  ('walk', 15),
#  ('israel', 15),
#  ('radio', 15),
#  ('started', 15),
#  ('department', 15),
#  ('earth', 15),
#  ('arrested', 15),
#  ('business', 15),
#  ('shift', 15),
#  ('waving', 15),
#  ('geller', 15),
#  ('king', 15),
#  ('research', 15),
#  ('problem', 15),
#  ('ahead', 15),
#  ('silver', 15),
#  ('dude', 15),
#  ('loving', 15),
#  ('super', 15),
#  ('tote', 15),
#  ('record', 15),
#  ('investigating', 15),
#  ('washington', 15),
#  ('coast', 15),
#  ('nagasaki', 15),
#  ('worse', 15),
#  ('course', 15),
#  ('disney', 15),
#  ('interesting', 15),
#  ('passengers', 15),
#  ('apollo', 15),
#  ('richmond', 15),
#  ('cree', 15),
#  ('12000', 15),
#  ('crematoria', 15),
#  ('colorado', 14),
#  ('myanmar', 14),
#  ('season', 14),
#  ('month', 14),
#  ('between', 14),
#  ('twelve', 14),
#  ('number', 14),
#  ('career', 14),
#  ('safety', 14),
#  ('took', 14),
#  ('mountain', 14),
#  ('girls', 14),
#  ('prepare', 14),
#  ('direction', 14),
#  ('indian', 14),
#  ('japanese', 14),
#  ('victims', 14),
#  ('cant', 14),
#  ('terror', 14),
#  ('piece', 14),
#  ('album', 14),
#  ('general', 14),
#  ('playlist', 14),
#  ('occurred', 14),
#  ('hair', 14),
#  ('expect', 14),
#  ('lady', 14),
#  ('giving', 14),
#  ('deep', 14),
#  ('open', 14),
#  ('aren', 14),
#  ('wall', 14),
#  ('mean', 14),
#  ('winds', 14),
#  ('sitting', 14),
#  ('strike', 14),
#  ('glad', 14),
#  ('small', 14),
#  ('idea', 14),
#  ('central', 14),
#  ('western', 14),
#  ('different', 14),
#  ('insurance', 14),
#  ('planned', 14),
#  ('#jobs', 14),
#  ('delivers', 14),
#  ('tree', 14),
#  ('govt', 14),
#  ('marians', 14),
#  ('internally', 14),
#  ('information', 14),
#  ('time2015', 14),
#  ('utc2015', 14),
#  ('provoke', 14),
#  ('jonathan', 14),
#  ('governor', 14),
#  ('alabama', 14),
#  ('recount', 14),
#  ('sent', 13),
#  ('lake', 13),
#  ('causes', 13),
#  ('office', 13),
#  ('wife', 13),
#  ('2013', 13),
#  ('teen', 13),
#  ('involving', 13),
#  ('double', 13),
#  ('happen', 13),
#  ('sunday', 13),
#  ('comment', 13),
#  ('using', 13),
#  ('financial', 13),
#  ('youtube', 13),
#  ('sometimes', 13),
#  ('pilot', 13),
#  ('victim', 13),
#  ('close', 13),
#  ('serious', 13),
#  ('nigga', 13),
#  ('fact', 13),
#  ('salt', 13),
#  ('horse', 13),
#  ('join', 13),
#  ('2014', 13),
#  ('played', 13),
#  ('queen', 13),
#  ('beat', 13),
#  ('loved', 13),
#  ('sense', 13),
#  ('haven', 13),
#  ('hero', 13),
#  ('suspected', 13),
#  ('nice', 13),
#  ('internet', 13),
#  ...]

# %% [markdown]
# ### Sacamos palabras que no son relevantes

# %%
#consideramos palabras vacias en ingles los articulos, pronombres, preposiciones,posesivos, entre otros
listaIrrelevante = ['i','you', 'he','she', 'it','we','they','my','your','his','her','their','our', 
                    'this', 'that', 'these', 'those','who', 'what', 'where', 'when', 'why', 'how' , 
                    'the','a','an','in','on','at','are','is','be','about','for','from','of','or','to',
                    'was','will','http','with','https','just','more','after','there','into','than',
                   'some','them','know','here','last','then','even','another','latest','every','most','before',
                   'always','does']

# %%
def quitarPalabrasVacias(unaLista, listaIrrelevante):
    return [w for w in unaLista if w not in listaIrrelevante]

# %%
df['text']= df['text'].apply(lambda unaLista: quitarPalabrasVacias(unaLista, listaIrrelevante) )
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN       [deeds, reason, #earthquake, allah, forgive]
# 1   4     NaN      NaN          [forest, fire, near, ronge, sask, canada]
# 2   5     NaN      NaN  [residents, asked, shelter, place, being, noti...
# 3   6     NaN      NaN  [people, receive, #wildfires, evacuation, orde...
# 4   7     NaN      NaN  [sent, photo, ruby, #alaska, smoke, #wildfires...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### ESTOS 2 RENGLONES SOLO ME SIRVE PARA VER QUE PALABRAS VACIAS SE LIMPIARON Y AUN FALTA SEGUIR ANALIZANDO CUALES SON CONSIDER
# RADAS VACIAS

# %%
lista={} #es la lista que generaremos de todas las palabras que exista en la columna text
a=df['text'].apply(lambda unaLista: contarFrecuenciaDePalabras(unaLista,lista))

# %%
palabraYFrecuencia=sorted(lista.items(), key= lambda x: x[1], reverse = True)
palabraYFrecuencia
# Out:
# [('have', 386),
#  ('like', 348),
#  ('fire', 250),
#  ('people', 198),
#  ('been', 191),
#  ('over', 190),
#  ('video', 162),
#  ('emergency', 153),
#  ('disaster', 150),
#  ('police', 142),
#  ('would', 137),
#  ('body', 130),
#  ('still', 129),
#  ('were', 126),
#  ('news', 121),
#  ('burning', 121),
#  ('back', 119),
#  ('storm', 119),
#  ('suicide', 119),
#  ('crash', 117),
#  ('california', 116),
#  ('time', 116),
#  ('buildings', 111),
#  ('first', 109),
#  ('going', 104),
#  ('bomb', 104),
#  ('fires', 101),
#  ('attack', 101),
#  ('today', 100),
#  ('love', 98),
#  ('year', 98),
#  ('killed', 98),
#  ('dead', 97),
#  ('world', 95),
#  ('nuclear', 95),
#  ('full', 94),
#  ('train', 93),
#  ('being', 90),
#  ('life', 89),
#  ('only', 89),
#  ('good', 89),
#  ('down', 88),
#  ('families', 87),
#  ('think', 86),
#  ('accident', 85),
#  ('many', 84),
#  ('watch', 84),
#  ('could', 83),
#  ('@youtube', 83),
#  ('home', 82),
#  ('2015', 81),
#  ('make', 80),
#  ('want', 80),
#  ('years', 79),
#  ('collapse', 75),
#  ('work', 74),
#  ('because', 74),
#  ('#news', 74),
#  ('death', 74),
#  ('mass', 74),
#  ('look', 73),
#  ('help', 73),
#  ('please', 73),
#  ('need', 72),
#  ('army', 72),
#  ('take', 72),
#  ('really', 71),
#  ('hiroshima', 71),
#  ('should', 70),
#  ('bombing', 70),
#  ('school', 68),
#  ('black', 68),
#  ('right', 68),
#  ('fatal', 67),
#  ('water', 66),
#  ('mh370', 65),
#  ('much', 64),
#  ('city', 64),
#  ('read', 64),
#  ('northern', 64),
#  ('wildfire', 64),
#  ('forest', 63),
#  ('never', 63),
#  ('obama', 63),
#  ('great', 62),
#  ('live', 61),
#  ('homes', 61),
#  ('legionnaires', 61),
#  ('bomber', 61),
#  ('wreck', 60),
#  ('reddit', 59),
#  ('atomic', 58),
#  ('typhoon', 58),
#  ('everyone', 57),
#  ('said', 57),
#  ('fear', 57),
#  ('near', 56),
#  ('getting', 56),
#  ('damage', 56),
#  ('shit', 56),
#  ('ever', 56),
#  ('come', 56),
#  ('under', 56),
#  ('injured', 56),
#  ('flames', 56),
#  ('content', 56),
#  ('while', 55),
#  ('feel', 55),
#  ('flood', 54),
#  ('floods', 54),
#  ('since', 53),
#  ('cross', 53),
#  ('found', 52),
#  ('state', 52),
#  ('hope', 52),
#  ('coming', 51),
#  ('night', 51),
#  ('next', 51),
#  ('stop', 51),
#  ('during', 51),
#  ('without', 51),
#  ('truck', 50),
#  ('debris', 50),
#  ('little', 50),
#  ('evacuation', 49),
#  ('area', 49),
#  ('times', 49),
#  ('which', 49),
#  ('well', 49),
#  ('japan', 49),
#  ('plan', 49),
#  ('smoke', 48),
#  ('face', 48),
#  ('cause', 48),
#  ('weather', 48),
#  ('wounded', 48),
#  ('malaysia', 48),
#  ('heat', 47),
#  ('wild', 47),
#  ('high', 47),
#  ('movie', 47),
#  ('through', 47),
#  ('confirmed', 47),
#  ('severe', 47),
#  ('flooding', 46),
#  ('check', 46),
#  ('fucking', 46),
#  ('explosion', 46),
#  ('looks', 46),
#  ('food', 46),
#  ('military', 46),
#  ('made', 46),
#  ('rain', 45),
#  ('best', 45),
#  ('bloody', 45),
#  ('services', 45),
#  ('blood', 45),
#  ('warning', 45),
#  ('weapon', 45),
#  ('says', 45),
#  ('sinking', 45),
#  ('thunderstorm', 45),
#  ('devastated', 45),
#  ('until', 44),
#  ('also', 44),
#  ('house', 44),
#  ('liked', 44),
#  ('fall', 44),
#  ('weapons', 44),
#  ('lightning', 44),
#  ('bags', 44),
#  ('natural', 44),
#  ('spill', 44),
#  ('injuries', 44),
#  ('loud', 44),
#  ('gonna', 43),
#  ('head', 43),
#  ('tonight', 43),
#  ('someone', 43),
#  ('screaming', 43),
#  ('family', 43),
#  ('again', 43),
#  ('missing', 43),
#  ('summer', 42),
#  ('injury', 42),
#  ('murder', 42),
#  ('wind', 42),
#  ('evacuate', 42),
#  ('trapped', 42),
#  ('collided', 42),
#  ('fatalities', 42),
#  ('whole', 41),
#  ('save', 41),
#  ('survive', 41),
#  ('hail', 41),
#  ('girl', 41),
#  ('released', 41),
#  ('attacked', 41),
#  ('explode', 41),
#  ('derailment', 41),
#  ('failure', 41),
#  ('harm', 41),
#  ('collision', 41),
#  ('rescue', 41),
#  ('migrants', 41),
#  ('thunder', 41),
#  ('wreckage', 41),
#  ('outbreak', 41),
#  ('photo', 40),
#  ('week', 40),
#  ('around', 40),
#  ('free', 40),
#  ('long', 40),
#  ('destroyed', 40),
#  ('post', 40),
#  ('bridge', 40),
#  ('hazard', 40),
#  ('china', 40),
#  ('deaths', 40),
#  ('panic', 40),
#  ('sinkhole', 40),
#  ('other', 39),
#  ('update', 39),
#  ('burned', 39),
#  ('road', 39),
#  ('game', 39),
#  ('island', 39),
#  ('ambulance', 39),
#  ('destroy', 39),
#  ('destruction', 39),
#  ('women', 39),
#  ('charged', 39),
#  ('fuck', 39),
#  ('story', 39),
#  ('keep', 39),
#  ('report', 39),
#  ('rescuers', 39),
#  ('lives', 39),
#  ('rescued', 39),
#  ('twister', 39),
#  ('windstorm', 39),
#  ('county', 38),
#  ('trauma', 38),
#  ('survivors', 38),
#  ('self', 38),
#  ('away', 38),
#  ('show', 38),
#  ('against', 38),
#  ('white', 38),
#  ('real', 38),
#  ('saudi', 38),
#  ('battle', 38),
#  ('bombed', 38),
#  ('hurricane', 38),
#  ('boat', 38),
#  ('ruin', 38),
#  ('service', 38),
#  ('dust', 38),
#  ('survived', 38),
#  ('sunk', 38),
#  ('wrecked', 38),
#  ('thing', 37),
#  ('crashed', 37),
#  ('august', 37),
#  ('violent', 37),
#  ('things', 37),
#  ('twitter', 37),
#  ('woman', 37),
#  ('half', 37),
#  ('displaced', 37),
#  ('hazardous', 37),
#  ('crush', 37),
#  ('curfew', 37),
#  ('devastation', 37),
#  ('famine', 37),
#  ('investigators', 37),
#  ('massacre', 37),
#  ('quarantine', 37),
#  ('structural', 37),
#  ('sandstorm', 37),
#  ('better', 36),
#  ('least', 36),
#  ('came', 36),
#  ('suspect', 36),
#  ('call', 36),
#  ('kills', 36),
#  ('change', 36),
#  ('mosque', 36),
#  ('terrorist', 36),
#  ('hostage', 36),
#  ('wanna', 36),
#  ('catastrophe', 36),
#  ('collapsed', 36),
#  ('danger', 36),
#  ('deluge', 36),
#  ('derailed', 36),
#  ('refugees', 36),
#  ('drowning', 36),
#  ('engulfed', 36),
#  ('screamed', 36),
#  ('bang', 36),
#  ('quarantined', 36),
#  ('tornado', 35),
#  ('wave', 35),
#  ('past', 35),
#  ('heard', 35),
#  ('airplane', 35),
#  ('phone', 35),
#  ('national', 35),
#  ('heart', 35),
#  ('tomorrow', 35),
#  ('part', 35),
#  ('group', 35),
#  ('power', 35),
#  ('bleeding', 35),
#  ('light', 35),
#  ('tragedy', 35),
#  ('blown', 35),
#  ('anniversary', 35),
#  ('cliff', 35),
#  ('hundreds', 35),
#  ('stock', 35),
#  ('derail', 35),
#  ('detonate', 35),
#  ('exploded', 35),
#  ('hijacker', 35),
#  ('inundated', 35),
#  ('screams', 35),
#  ('whirlwind', 35),
#  ('horrible', 34),
#  ('left', 34),
#  ('meltdown', 34),
#  ('plane', 34),
#  ('must', 34),
#  ('went', 34),
#  ('blew', 34),
#  ('drown', 34),
#  ('rioting', 34),
#  ('riot', 34),
#  ('traumatised', 34),
#  ('casualties', 34),
#  ('landslide', 34),
#  ('wounds', 34),
#  ('desolation', 34),
#  ('electrocuted', 34),
#  ('hostages', 34),
#  ('razed', 34),
#  ('something', 33),
#  ('thank', 33),
#  ('reunion', 33),
#  ('iran', 33),
#  ('zone', 33),
#  ('soon', 33),
#  ('apocalypse', 33),
#  ('land', 33),
#  ('bagging', 33),
#  ('caused', 33),
#  ('drought', 33),
#  ('catastrophic', 33),
#  ('affected', 33),
#  ('collide', 33),
#  ('demolish', 33),
#  ('trouble', 33),
#  ('evacuated', 33),
#  ('flattened', 33),
#  ('lava', 33),
#  ('murderer', 33),
#  ('mudslide', 33),
#  ('panicking', 33),
#  ('south', 32),
#  ('very', 32),
#  ('minute', 32),
#  ('doing', 32),
#  ('possible', 32),
#  ('sure', 32),
#  ('river', 32),
#  ('kill', 32),
#  ('fedex', 32),
#  ('market', 32),
#  ('send', 32),
#  ('fatality', 32),
#  ('hijacking', 32),
#  ('pandemonium', 32),
#  ('three', 31),
#  ('breaking', 31),
#  ('kids', 31),
#  ('america', 31),
#  ('goes', 31),
#  ('government', 31),
#  ('annihilated', 31),
#  ('thought', 31),
#  ('arson', 31),
#  ('terrorism', 31),
#  ('officials', 31),
#  ('longer', 31),
#  ('blazing', 31),
#  ('song', 31),
#  ('baby', 31),
#  ('casualty', 31),
#  ('chemical', 31),
#  ('responders', 31),
#  ('crushed', 31),
#  ('detonation', 31),
#  ('drowned', 31),
#  ('earthquake', 31),
#  ('obliterated', 31),
#  ('rainstorm', 31),
#  ('detonated', 31),
#  ('building', 30),
#  ('thanks', 30),
#  ('care', 30),
#  ('used', 30),
#  ('issues', 30),
#  ('same', 30),
#  ('fight', 30),
#  ('armageddon', 30),
#  ('sound', 30),
#  ('stay', 30),
#  ('beautiful', 30),
#  ('calgary', 30),
#  ('bioterror', 30),
#  ('nothing', 30),
#  ('shoulder', 30),
#  ('officer', 30),
#  ('cyclone', 30),
#  ('blast', 30),
#  ('demolition', 30),
#  ('volcano', 30),
#  ('tsunami', 30),
#  ('electrocute', 30),
#  ('#hot', 30),
#  ('#prebreak', 30),
#  ('#best', 30),
#  ('obliterate', 30),
#  ('siren', 30),
#  ('days', 29),
#  ('cool', 29),
#  ('already', 29),
#  ('making', 29),
#  ('done', 29),
#  ('believe', 29),
#  ('ebay', 29),
#  ('hours', 29),
#  ('start', 29),
#  ('media', 29),
#  ('remember', 29),
#  ('security', 29),
#  ('bush', 29),
#  ('demolished', 29),
#  ('airport', 29),
#  ('eyewitness', 29),
#  ('obliteration', 29),
#  ('offensive', 29),
#  ('upheaval', 29),
#  ('died', 28),
#  ('second', 28),
#  ('ablaze', 28),
#  ('inside', 28),
#  ('leave', 28),
#  ('traffic', 28),
#  ('shooting', 28),
#  ('actually', 28),
#  ('wake', 28),
#  ('sirens', 28),
#  ('peace', 28),
#  ('person', 28),
#  ('music', 28),
#  ('having', 28),
#  ('words', 28),
#  ('blight', 28),
#  ('such', 28),
#  ('turkey', 28),
#  ('hellfire', 28),
#  ('hijack', 28),
#  ('16yr', 28),
#  ('both', 27),
#  ('site', 27),
#  ('shot', 27),
#  ('north', 27),
#  ('support', 27),
#  ('plans', 27),
#  ('play', 27),
#  ('stand', 27),
#  ('order', 27),
#  ('israeli', 27),
#  ('trying', 27),
#  ('line', 27),
#  ('policy', 27),
#  ('nearby', 27),
#  ('deluged', 27),
#  ('declares', 27),
#  ('seismic', 27),
#  ('reactor', 27),
#  ('snowstorm', 27),
#  ('place', 26),
#  ('wait', 26),
#  ('west', 26),
#  ('didn', 26),
#  ('gets', 26),
#  ('yourself', 26),
#  ('brown', 26),
#  ('anything', 26),
#  ('yeah', 26),
#  ('guys', 26),
#  ('deal', 26),
#  ('doesn', 26),
#  ('find', 26),
#  ('memories', 26),
#  ('soudelor', 26),
#  ('rubble', 26),
#  ('swallowed', 26),
#  ('lost', 25),
#  ('outside', 25),
#  ('tell', 25),
#  ('almost', 25),
#  ('country', 25),
#  ('horror', 25),
#  ('hell', 25),
#  ('maybe', 25),
#  ('data', 25),
#  ('children', 25),
#  ('american', 25),
#  ('health', 25),
#  ('photos', 25),
#  ('watching', 25),
#  ('bigger', 25),
#  ('rise', 25),
#  ('desolate', 25),
#  ('saipan', 25),
#  ('conclusively', 25),
#  ('street', 24),
#  ('side', 24),
#  ('center', 24),
#  ('anyone', 24),
#  ('helicopter', 24),
#  ('history', 24),
#  ('pick', 24),
#  ('control', 24),
#  ('makes', 24),
#  ('literally', 24),
#  ('transport', 24),
#  ('bioterrorism', 24),
#  ('searching', 24),
#  ('hear', 24),
#  ('crews', 24),
#  ('waves', 24),
#  ('bodies', 24),
#  ('projected', 24),
#  ('happy', 23),
#  ('#nowplaying', 23),
#  ('finally', 23),
#  ('might', 23),
#  ('eyes', 23),
#  ('everything', 23),
#  ('amid', 23),
#  ('blaze', 23),
#  ('damn', 23),
#  ('team', 23),
#  ('feeling', 23),
#  ('avalanche', 23),
#  ('hollywood', 23),
#  ('pretty', 23),
#  ('book', 23),
#  ('move', 23),
#  ('online', 23),
#  ('though', 23),
#  ('probably', 23),
#  ('myself', 23),
#  ('saved', 23),
#  ('trains', 23),
#  ('aircraft', 23),
#  ('signs', 23),
#  ('effect', 23),
#  ('#islam', 23),
#  ('manslaughter', 23),
#  ('trench', 23),
#  ('fast', 22),
#  ('property', 22),
#  ('once', 22),
#  ('wrong', 22),
#  ('feared', 22),
#  ('hate', 22),
#  ('seen', 22),
#  ('case', 22),
#  ('annihilation', 22),
#  ('major', 22),
#  ('child', 22),
#  ('name', 22),
#  ('crisis', 22),
#  ('leather', 22),
#  ('caught', 22),
#  ('town', 22),
#  ('okay', 22),
#  ('youth', 22),
#  ('space', 22),
#  ('nearly', 22),
#  ('morning', 22),
#  ('money', 22),
#  ('spot', 22),
#  ('#hiroshima', 22),
#  ('sensor', 22),
#  ('refugio', 22),
#  ('costlier', 22),
#  ('stretcher', 22),
#  ('miners', 22),
#  ('flash', 21),
#  ('flag', 21),
#  ('cars', 21),
#  ('lord', 21),
#  ('arsonist', 21),
#  ('huge', 21),
#  ('vehicle', 21),
#  ('daily', 21),
#  ('ship', 21),
#  ('crazy', 21),
#  ('sorry', 21),
#  ('ball', 21),
#  ('called', 21),
#  ('class', 21),
#  ('east', 21),
#  ('texas', 21),
#  ('india', 21),
#  ('worst', 21),
#  ('needs', 21),
#  ('giant', 21),
#  ('angry', 21),
#  ('isis', 21),
#  ('image', 21),
#  ('banned', 21),
#  ('knock', 21),
#  ('picking', 21),
#  ('reason', 20),
#  ('closed', 20),
#  ('heavy', 20),
#  ('across', 20),
#  ('haha', 20),
#  ('hard', 20),
#  ('others', 20),
#  ('talk', 20),
#  ('official', 20),
#  ('sign', 20),
#  ('poor', 20),
#  ('action', 20),
#  ('toddler', 20),
#  ('united', 20),
#  ('blue', 20),
#  ('star', 20),
#  ('australia', 20),
#  ('running', 20),
#  ('looking', 20),
#  ('dont', 20),
#  ('entire', 20),
#  ('level', 20),
#  ('link', 20),
#  ('meek', 20),
#  ('houses', 20),
#  ('become', 20),
#  ('chance', 20),
#  ('friends', 20),
#  ('ignition', 20),
#  ('#earthquake', 19),
#  ('wanted', 19),
#  ('thousands', 19),
#  ('alone', 19),
#  ('yours', 19),
#  ('else', 19),
#  ('happened', 19),
#  ('drive', 19),
#  ('couple', 19),
#  ('pakistan', 19),
#  ('totally', 19),
#  ('learn', 19),
#  ('beach', 19),
#  ('reports', 19),
#  ('christian', 19),
#  ('muslims', 19),
#  ('temple', 19),
#  ('view', 19),
#  ('taken', 19),
#  ('playing', 19),
#  ('anthrax', 19),
#  ('mishaps', 19),
#  ('public', 19),
#  ('computers', 19),
#  ('cake', 19),
#  ('pain', 19),
#  ('blizzard', 19),
#  ('large', 19),
#  ('ladies', 19),
#  ('appears', 19),
#  ('listen', 19),
#  ('centre', 19),
#  ('village', 19),
#  ('alarm', 19),
#  ('takes', 19),
#  ('issued', 19),
#  ('declaration', 19),
#  ('disea', 19),
#  ('chicago', 18),
#  ('front', 18),
#  ('aftershock', 18),
#  ('experts', 18),
#  ('trust', 18),
#  ('ready', 18),
#  ('human', 18),
#  ('film', 18),
#  ('till', 18),
#  ('friend', 18),
#  ('green', 18),
#  ('mount', 18),
#  ('driving', 18),
#  ('favorite', 18),
#  ('germs', 18),
#  ('info', 18),
#  ('drake', 18),
#  ('russian', 18),
#  ('middle', 18),
#  ('marks', 18),
#  ('thursday', 18),
#  ('#gbbo', 18),
#  ('downtown', 18),
#  ('british', 18),
#  ('instead', 18),
#  ('coaches', 18),
#  ('flight', 18),
#  ('quiz', 18),
#  ('virgin', 18),
#  ('bestnaijamade', 18),
#  ('bring', 17),
#  ('taking', 17),
#  ('reported', 17),
#  ('dies', 17),
#  ('turned', 17),
#  ('global', 17),
#  ('moment', 17),
#  ('behind', 17),
#  ('four', 17),
#  ('wednesday', 17),
#  ('early', 17),
#  ('reuters', 17),
#  ('driver', 17),
#  ('park', 17),
#  ('following', 17),
#  ('disease', 17),
#  ('comes', 17),
#  ('scared', 17),
#  ('escape', 17),
#  ('true', 17),
#  ('theater', 17),
#  ('gave', 17),
#  ('added', 17),
#  ('climate', 17),
#  ('party', 17),
#  ('turn', 17),
#  ('follow', 17),
#  ('fans', 17),
#  ('point', 17),
#  ('outrage', 17),
#  ('camp', 17),
#  ('sounds', 17),
#  ('landing', 17),
#  ('york', 17),
#  ('patience', 17),
#  ('former', 17),
#  ('madhya', 17),
#  ('pradesh', 17),
#  ('wonder', 17),
#  ('bayelsa', 17),
#  ('gems', 17),
#  ('funtenna', 17),
#  ('ancient', 17),
#  ('subreddits', 17),
#  ('galactic', 17),
#  ('awesome', 16),
#  ('upon', 16),
#  ('shots', 16),
#  ('risk', 16),
#  ('scene', 16),
#  ('seeing', 16),
#  ('thinking', 16),
#  ('mode', 16),
#  ('pakistani', 16),
#  ('wasn', 16),
#  ('share', 16),
#  ('give', 16),
#  ('series', 16),
#  ('hand', 16),
#  ('working', 16),
#  ('date', 16),
#  ('shows', 16),
#  ('lmao', 16),
#  ('claims', 16),
#  ('militants', 16),
#  ('bombs', 16),
#  ('pamela', 16),
#  ('young', 16),
#  ('miss', 16),
#  ('niggas', 16),
#  ('tweet', 16),
#  ('enough', 16),
#  ('told', 16),
#  ('falling', 16),
#  ('soul', 16),
#  ('rock', 16),
#  ('biggest', 16),
#  ('russia', 16),
#  ('pray', 16),
#  ('70th', 16),
#  ('holding', 16),
#  ('likely', 16),
#  ('businesses', 16),
#  ('room', 16),
#  ('download', 16),
#  ('break', 16),
#  ('sick', 16),
#  ('rules', 16),
#  ('lamp', 16),
#  ('hailstorm', 16),
#  ('nigerian', 16),
#  ('parole', 16),
#  ('unconfirmed', 16),
#  ('neighbour', 16),
#  ('mayhem', 16),
#  ('chile', 16),
#  ('expected', 15),
#  ('london', 15),
#  ('means', 15),
#  ('secret', 15),
#  ('guess', 15),
#  ('wants', 15),
#  ('tried', 15),
#  ('france', 15),
#  ('members', 15),
#  ('petition', 15),
#  ('hour', 15),
#  ('walk', 15),
#  ('israel', 15),
#  ('radio', 15),
#  ('started', 15),
#  ('department', 15),
#  ('earth', 15),
#  ('arrested', 15),
#  ('business', 15),
#  ('shift', 15),
#  ('waving', 15),
#  ('geller', 15),
#  ('king', 15),
#  ('research', 15),
#  ('problem', 15),
#  ('ahead', 15),
#  ('silver', 15),
#  ('dude', 15),
#  ('loving', 15),
#  ('super', 15),
#  ('tote', 15),
#  ('record', 15),
#  ('investigating', 15),
#  ('washington', 15),
#  ('coast', 15),
#  ('nagasaki', 15),
#  ('worse', 15),
#  ('course', 15),
#  ('disney', 15),
#  ('interesting', 15),
#  ('passengers', 15),
#  ('apollo', 15),
#  ('richmond', 15),
#  ('cree', 15),
#  ('12000', 15),
#  ('crematoria', 15),
#  ('colorado', 14),
#  ('myanmar', 14),
#  ('season', 14),
#  ('month', 14),
#  ('between', 14),
#  ('twelve', 14),
#  ('number', 14),
#  ('career', 14),
#  ('safety', 14),
#  ('took', 14),
#  ('mountain', 14),
#  ('girls', 14),
#  ('prepare', 14),
#  ('direction', 14),
#  ('indian', 14),
#  ('japanese', 14),
#  ('victims', 14),
#  ('cant', 14),
#  ('terror', 14),
#  ('piece', 14),
#  ('album', 14),
#  ('general', 14),
#  ('playlist', 14),
#  ('occurred', 14),
#  ('hair', 14),
#  ('expect', 14),
#  ('lady', 14),
#  ('giving', 14),
#  ('deep', 14),
#  ('open', 14),
#  ('aren', 14),
#  ('wall', 14),
#  ('mean', 14),
#  ('winds', 14),
#  ('sitting', 14),
#  ('strike', 14),
#  ('glad', 14),
#  ('small', 14),
#  ('idea', 14),
#  ('central', 14),
#  ('western', 14),
#  ('different', 14),
#  ('insurance', 14),
#  ('planned', 14),
#  ('#jobs', 14),
#  ('delivers', 14),
#  ('tree', 14),
#  ('govt', 14),
#  ('marians', 14),
#  ('internally', 14),
#  ('information', 14),
#  ('time2015', 14),
#  ('utc2015', 14),
#  ('provoke', 14),
#  ('jonathan', 14),
#  ('governor', 14),
#  ('alabama', 14),
#  ('recount', 14),
#  ('sent', 13),
#  ('lake', 13),
#  ('causes', 13),
#  ('office', 13),
#  ('wife', 13),
#  ('2013', 13),
#  ('teen', 13),
#  ('involving', 13),
#  ('double', 13),
#  ('happen', 13),
#  ('sunday', 13),
#  ('comment', 13),
#  ('using', 13),
#  ('financial', 13),
#  ('youtube', 13),
#  ('sometimes', 13),
#  ('pilot', 13),
#  ('victim', 13),
#  ('close', 13),
#  ('serious', 13),
#  ('nigga', 13),
#  ('fact', 13),
#  ('salt', 13),
#  ('horse', 13),
#  ('join', 13),
#  ('2014', 13),
#  ('played', 13),
#  ('queen', 13),
#  ('beat', 13),
#  ('loved', 13),
#  ('sense', 13),
#  ('haven', 13),
#  ('hero', 13),
#  ('suspected', 13),
#  ('nice', 13),
#  ('internet', 13),
#  ('worry', 13),
#  ('response', 13),
#  ('answer', 13),
#  ('mine', 13),
#  ('games', 13),
#  ('cover', 13),
#  ('threat', 13),
#  ('living', 13),
#  ('weekend', 13),
#  ('firefighters', 13),
#  ('agree', 13),
#  ('cold', 13),
#  ('walking', 13),
#  ('gone', 13),
#  ('broke', 13),
#  ('standard', 13),
#  ('friday', 13),
#  ('hasn', 13),
#  ('faux', 13),
#  ('saying', 13),
#  ('gunman', 13),
#  ('islamic', 13),
#  ('ground', 13),
#  ('five', 13),
#  ('parents', 13),
#  ('press', 13),
#  ('account', 13),
#  ('strong', 13),
#  ('felt', 13),
#  ('absolutely', 13),
#  ('president', 13),
#  ('force', 13),
#  ('airlines', 13),
#  ('evening', 13),
#  ('enugu', 13),
#  ('spring', 13),
#  ...]

# %% [markdown]
# ### Tendencias
#
# El nro de tweets = nro palabras relevantes que se repite en distintos tweet
#
# 1) Se considerara tendencia el nro tweets relacionado con la location
#
# 2) Se considera tendencia el nro tweets relacionado con keyword
#
# 3) Se considera tendencia el nro de tweets relacionado con keyword y location
#
# 4) Si hay tendencias y # que se relacionan con un mismo keyword, se considerara lo mismo #CovidArgentina = #ArgentinaCovid
#
# 5) Tendencia por cuenta; se considera por keyword y @
